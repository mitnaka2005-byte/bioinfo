# %%
# Inspect Hi-C format before final conversion
import gzip
f='organized/HiC/GSM4710397_NSC_rep1_hic.txt.gz'

with gzip.open(f,'rt') as fh:
    for i,line in enumerate(fh):
        print(line.rstrip())
        if i>20: break

# After confirming format, use cooler create/cload workflow.
