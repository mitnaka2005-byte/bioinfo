# %%
import tarfile, pandas as pd

tar_path = 'organized/MPRA/GSM5583720_MPRA_pool_rep1_rep2.tar.gz'

with tarfile.open(tar_path,'r:gz') as tar:
    dna_counts = pd.read_csv(tar.extractfile('dna_counts.tsv'), sep='\t')
    rna_counts = pd.read_csv(tar.extractfile('rna_counts.tsv'), sep='\t')
    dna_annot = pd.read_csv(tar.extractfile('dna_annot.tsv'), sep='\t')
    rna_annot = pd.read_csv(tar.extractfile('rna_annot.tsv'), sep='\t')

print(dna_counts.shape)
print(rna_counts.shape)
display(dna_counts.head())
